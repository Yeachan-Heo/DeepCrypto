# %%
from deepcrypto.data_utils.crawlers.bitmex import *
from deepcrypto.data_utils import *
from deepcrypto.backtest import *
from deepcrypto.portfolio_analysis import all_metrics, save_results

from scipy import stats
from sklearn.linear_model import LogisticRegression, LinearRegression
from warnings import filterwarnings

import quantstats as qs

# %%
np.random.seed(5)

# %%
filterwarnings("ignore")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
plt.style.use("seaborn")

# %%
PERIOD = 200
SYMBOL = "ETHUSD"

# %%
df = load_bitmex_data("/home/ych/Storage/bitmex/bitmex.db", "1H", SYMBOL)

# %%
df = df.backtest.add_defaults()

# %%
df["return"] = df["close"].pct_change(PERIOD)
df["future_return"] = df["return"].shift(-PERIOD)

# %%
df[f"mean"] = df["close"].rolling(PERIOD).mean()
df[f"std"] = df["close"].rolling(PERIOD).std()

# %%
df = df.dropna()

# %%
df[f"pdf"] = stats.norm(df[f"mean"], df[f"std"]).pdf(df["close"])
df[f"entropy"] = -df["pdf"] * np.log2(df["pdf"])

# %%
df["entropy"].rolling(PERIOD).mean().plot(color="blue")
plt.ylabel("entropy")
# Out:
# Text(0, 0.5, 'entropy')

# %%
df["skewness"] = df["close"].rolling(PERIOD).skew().abs()

# %%
df["skewness"].hist(color="blue")
plt.ylabel("skewness")
# Out:
# Text(0, 0.5, 'skewness')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23351 entries, 2018-08-10 17:00:00 to 2021-04-09 15:00:00
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      23351 non-null  object
#  1   open           23351 non-null  float64
#  2   high           23351 non-null  float64
#  3   low            23351 non-null  float64
#  4   close          23351 non-null  float64
#  5   volume         23351 non-null  float64
#  6   lowFirst       23351 non-null  float64
#  7   enter_long     23351 non-null  int64
#  8   enter_short    23351 non-null  int64
#  9   close_long     23351 non-null  int64
#  10  close_short    23351 non-null  int64
#  11  bet            23351 non-null  int64
#  12  stop_loss      23351 non-null  float64
#  13  take_profit    23351 non-null  float64
#  14  time_cut       23351 non-null  float64
#  15  trade_cost     23351 non-null  int64
#  16  slippage       23351 non-null  int64
#  17  low_first      23351 non-null  int64
#  18  return         23351 non-null  float64
#  19  future_return  23351 non-null  float64
#  20  mean           23351 non-null  float64
#  21  std            23351 non-null  float64
#  22  pdf            23351 non-null  float64
#  23  entropy        23351 non-null  float64
#  24  skewness       23152 non-null  float64
# dtypes: float64(16), int64(8), object(1)
# memory usage: 4.6+ MB

# %%
c = df[-PERIOD:].entropy.values 
dates = df[-PERIOD:].index.values
y = df[-PERIOD:].close.values

from matplotlib.collections import LineCollection
import matplotlib.dates as mdates

fig, ax = plt.subplots()

#convert dates to numbers first
inxval = mdates.date2num(dates)
points = np.array([inxval, y]).T.reshape(-1,1,2)
segments = np.concatenate([points[:-1],points[1:]], axis=1)

lc = LineCollection(segments, cmap="rainbow", linewidth=3)
# set color to date values
lc.set_array(c)
ax.add_collection(lc)

loc = mdates.AutoDateLocator()
ax.xaxis.set_major_locator(loc)
ax.xaxis.set_major_formatter(mdates.AutoDateFormatter(loc))
ax.autoscale_view()
plt.show()

# %%
c = df[-PERIOD:].skewness.values 
dates = df[-PERIOD:].index.values
y = df[-PERIOD:].close.values

from matplotlib.collections import LineCollection
import matplotlib.dates as mdates

fig, ax = plt.subplots()

#convert dates to numbers first
inxval = mdates.date2num(dates)
points = np.array([inxval, y]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1],points[1:]], axis=1)

lc = LineCollection(segments, cmap="rainbow", linewidth=3)
# set color to date values
lc.set_array(c)
ax.add_collection(lc)

loc = mdates.AutoDateLocator()
ax.xaxis.set_major_locator(loc)
ax.xaxis.set_major_formatter(mdates.AutoDateFormatter(loc))
ax.autoscale_view()
plt.show()

# %%
plt.scatter(df["entropy"], df["return"].shift(-PERIOD) * 100, c=-df["entropy"], cmap=plt.cm.rainbow)
plt.xlabel("entropy")
plt.ylabel(f"change(%) for {PERIOD}")
# Out:
# Text(0, 0.5, 'change(%) for 200')

# %%
plt.scatter(
    df["entropy"], 
    df["return"].rolling(PERIOD).std().shift(-PERIOD) * 100, 
    c=-df["entropy"], 
    cmap=plt.cm.rainbow
)
plt.xlabel("entropy")
plt.ylabel(f"stdev for returns(%) for {PERIOD}")
# Out:
# Text(0, 0.5, 'stdev for returns(%) for 200')

# %%
df_highent = df[(df["entropy"] < 0.2)]
df_highent = df[(df["skewness"]) < 1]

# %%
df_linreg = df_highent[["return", "future_return", "entropy"]]
df_linreg["future_return_mean"] = df_linreg["future_return"].rolling(PERIOD).mean()
df_linreg = df_linreg.dropna()

# %%
regressor = LinearRegression()
regressor.fit(df_linreg["return"].values.reshape(-1, 1), df_linreg["future_return_mean"].values.reshape(-1, 1))
# Out:
# LinearRegression()

# %%
reg_X = np.array(sorted(df_linreg["return"].values)).reshape(-1, 1)
reg_pred = regressor.predict(reg_X)
reg_X = reg_X.squeeze()

# %%
np.random.seed(42)
index = np.random.randint(0, len(reg_X), size=1000)
plt.scatter(
    df_linreg["return"].iloc[index],
    df_linreg["future_return_mean"].iloc[index],
    c=df_linreg["entropy"].iloc[index],
    cmap=plt.cm.winter,
    alpha=0.3,
)

plt.plot(
    reg_X, 
    reg_pred,
    color="red",
    linewidth=3,
    label="linear regression"
)

plt.xlabel("return")
plt.ylabel("mean of future return")
plt.legend()

# %%
df_linreg[["return", "future_return_mean"]].corr()
# Out:
#                       return  future_return_mean
# return              1.000000            0.711148
# future_return_mean  0.711148            1.000000

# %%
(df["close"].pct_change().rolling(PERIOD).std()["2017-03-01":]).hist()
# Out:
# <AxesSubplot:>

# %%
(df["close"].pct_change().rolling(PERIOD).std()[:"2017-03-01"]).hist()
# Out:
# <AxesSubplot:>

# %%
from talib.abstract import *
from ray import tune
from copy import deepcopy
import ray

# %%
df
# Out:
#                                timestamp     open     high      low    close  \
# timestamp
# 2018-08-10 17:00:00  2018-08-10 17:00:00   357.90   360.30   356.50   358.20
# 2018-08-10 18:00:00  2018-08-10 18:00:00   358.15   358.50   356.70   357.15
# 2018-08-10 19:00:00  2018-08-10 19:00:00   357.15   357.25   356.20   356.50
# 2018-08-10 20:00:00  2018-08-10 20:00:00   356.45   356.80   340.45   342.80
# 2018-08-10 21:00:00  2018-08-10 21:00:00   342.80   342.80   324.80   325.70
# ...                                  ...      ...      ...      ...      ...
# 2021-04-09 11:00:00  2021-04-09 11:00:00  2091.35  2096.55  2083.40  2086.35
# 2021-04-09 12:00:00  2021-04-09 12:00:00  2087.25  2094.00  2076.25  2082.15
# 2021-04-09 13:00:00  2021-04-09 13:00:00  2082.15  2088.45  2073.70  2077.90
sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-04-27_15-37-42_344414_13113/sockets/raylet',
#  'webui_url': '127.0.0.1:8266',
#  'session_dir': '/tmp/ray/session_2021-04-27_15-37-42_344414_13113',
#  'metrics_export_port': 53731,
#  'node_id': '7086fc50dc366bbbe51d6271269056fa530b324cd823c9d97eddaa9f'}

# %%
from deepcrypto.backtest import BacktestAccessor
import quantstats as qs

# %%
@strategy
def entropy_strategy(config, df):
    PERIOD = config["PERIOD"]
    RSI_PERIOD = config["RSI_PERIOD"]
    RETURN_PERIOD = config["RETURN_PERIOD"]
    ENTROPY_THRES = config["ENTROPY_THRES"]
    STOP_LOSS = config["STOP_LOSS"]
    TAKE_PROFIT = config["TAKE_PROFIT"]
    TIME_CUT = config["TIME_CUT"]
    SKEW_THRES = config["SKEW_THRES"]
    
    df.backtest.add_defaults()

    df["mean"] = df["close"].rolling(PERIOD).mean()
    df["std"] = df["close"].rolling(PERIOD).std()
    
    df["return"] = df["close"].pct_change(RETURN_PERIOD)
    
    df["pdf"] = stats.norm(df[f"mean"], df[f"std"]).pdf(df["close"])

    df["entropy"] = -df["pdf"] * np.log2(df["pdf"])
    
    df["skewness"] = df["close"].rolling(PERIOD).skew().abs()

    df["RSI"] = RSI(df["close"], RSI_PERIOD)

    df["enter_long"] = (
        (df["return"] > 0) 
        & (df["entropy"] < ENTROPY_THRES)  
        & (df["RSI"] > 50) 
        & (df["close"]/df["mean"] > 1)
        & (df["skewness"] < SKEW_THRES)
    )
    
    df["close_long"] = df["entropy"] > ENTROPY_THRES

    df["enter_short"] = (
        (df["return"] < 0) 
        & (df["entropy"] < ENTROPY_THRES) 
        & (df["RSI"] < 50) 
        & (df["close"]/df["mean"] < 1)
        & (df["skewness"] < SKEW_THRES)
    )
    df["close_short"] = df["entropy"] > ENTROPY_THRES

    df["time_cut"] = TIME_CUT
    df["bet"] = np.clip(0.005/df["close"].pct_change().rolling(PERIOD).std(), 0, 3) * 10
    df["trade_cost"] = 0.001
    df["take_profit"] = TAKE_PROFIT
    df["stop_loss"] = STOP_LOSS
    df["low_first"] = 1
    return df

def optimizer(config, df):
    from deepcrypto.backtest import BacktestAccessor
    portfolio_df, order_df = entropy_strategy(config, df).backtest.run()
    tune.report(**all_metrics(portfolio_df, order_df))

# %%
def optimize(df):
    result = tune.run(
        tune.with_parameters(optimizer, df=df),
        config = {
            "PERIOD" : tune.grid_search([50, 100, 200]),
            "RSI_PERIOD" : tune.grid_search([50, 100, 200]),
            "RETURN_PERIOD" : tune.grid_search([50, 100, 200]),
            "ENTROPY_THRES" : tune.grid_search([0.2, 0.3]),
            "STOP_LOSS" : tune.grid_search([0.02, 0.05]),
            "TAKE_PROFIT" : tune.grid_search([0.1, 0.2]),
            "TIME_CUT" : tune.grid_search([50, 100, 200]),
            "SKEW_THRES" : tune.grid_search([1, 2, 3])
        },
        local_dir="./ray_results",
    )
    return result

# %%
import quantstats as qs
import json, os
from pprint import pprint

do_optimize=False

if do_optimize:
    result = optimize(df[:-1])


    save_dir = f"./result/new/{SYMBOL}/"

    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    from deepcrypto.portfolio_analysis import save_results

    result = tune.Analysis("/home/ych/WorkSpace/Projects/DeepCrypto/research/entropy_strategy/ray_results/_inner_2021-04-20_00-56-33")

    save_results(result.get_best_config(metric="Calmar", mode="max"), entropy_strategy, df, save_dir, "Calmar")
    save_results(result.get_best_config(metric="Sortino", mode="max"), entropy_strategy, df, save_dir, "Sortino")
    save_results(result.get_best_config(metric="MaxDrawdown", mode="max"), entropy_strategy, df, save_dir, "MaxDrawdown")
    save_results(result.get_best_config(metric="CAGR%", mode="max"), entropy_strategy, df, save_dir, "CAGR")

# %%
cfg = {"ENTROPY_THRES": 0.3, "PERIOD": 100, "RETURN_PERIOD": 50, "RSI_PERIOD": 200, "SKEW_THRES": 1, "STOP_LOSS": 0.01, "TAKE_PROFIT": 0.2, "TIME_CUT": 360000000000000.0/TIMEFRAMES.HOUR}

port, order = entropy_strategy(cfg, df).backtest.run(simple_interest=True)

qs.reports.full(port["portfolio_value"])
# Out:
# backtest completed in 0.038965702056884766 seconds
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2018-08-19
# End Period                 2021-04-09
# Risk-Free Rate             0.0%
# Time in Market             60.0%
#
# Cumulative Return          2,696.65%
# CAGR%                      252.97%
# Sharpe                     0.28
# Sortino                    0.62
# Max Drawdown               -66.07%
# Longest DD Days            210
# Volatility (ann.)          17.47%
# Calmar                     3.83
# Skew                       31.01
# Kurtosis                   1953.5
#
# Expected Daily %           0.01%
# Expected Monthly %         10.62%
# Expected Yearly %          129.96%
# Kelly Criterion            7.09%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -1.79%
# Expected Shortfall (cVaR)  -3.8%
#
# Payoff Ratio               1.26
# Profit Factor              0.17
# Common Sense Ratio         0.19
# CPC Index                  0.1
# Tail Ratio                 1.08
# Outlier Win Ratio          10.04
# Outlier Loss Ratio         4.76
#
# MTD                        0.31%
# 3M                         7.27%
# 6M                         21.55%
# YTD                        12.91%
# 1Y                         40.45%
# 3Y (ann.)                  252.97%
# 5Y (ann.)                  252.97%
# 10Y (ann.)                 252.97%
# All-time (ann.)            252.97%
#
# Best Day                   79.88%
# Worst Day                  -24.74%
# Best Month                 273.25%
# Worst Month                -14.24%
# Best Year                  843.12%
# Worst Year                 12.91%
#
# Avg. Drawdown              -2.46%
# Avg. Drawdown Days         4
# Recovery Factor            40.81
# Ulcer Index                inf
#
# Avg. Up Month              25.14%
# Avg. Down Month            -6.24%
# Win Days %                 48.15%
# Win Month %                72.73%
# Win Quarter %              75.0%
# Win Year %                 100.0%
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2018-08-22  2018-09-04  2018-09-05    13    -66.071000        -63.578667
# 2  2018-09-12  2018-10-11  2018-11-04    53    -49.469642        -45.879431
# 3  2018-08-21  2018-08-22  2018-08-22     1    -25.396306        -24.453520
# 4  2019-02-19  2019-06-12  2019-09-17   210    -25.291193        -23.857792
# 5  2018-11-07  2018-11-13  2018-11-14     7    -22.207458        -20.552651
# <h4>Strategy Visualization</h4>

# %%
(order.timestamp.diff() / TIMEFRAMES.DAY).mean()

# %%
order.realized.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
(np.maximum.accumulate(port.portfolio_value) - port.portfolio_value).max() / port.portfolio_value.iloc[0] * 100
# Out:
# 319.8807844356325

# %%
order.realized_percent.cumsum().plot()
# Out:
# <AxesSubplot:>
